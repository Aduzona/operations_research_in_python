# %%
import numpy as np
from geneticalgorithm import geneticalgorithm as ga

# %% [markdown]
# # Model
#
# $$\max x+y*x$$
#
# s.t.
#
# $$-x+2*y*x<=8$$
# $$2*x+y<=14$$
# $$2*x-y<=10$$

# %%
def f(x):
    pen = 0
    if not -x[0]+2*x[1]*x[0]<=8: pen = np.inf
    if not 2*x[0]+x[1]<=14: pen = np.inf
    if not 2*x[0]-x[1]<=10: pen = np.inf
    return -(x[0]+x[1]*x[0]) + pen

# %% [markdown]
# $$0<x<10$$
# $$0<y<10$$
# $$x \in \mathbb Z_+$$
# $$y \in \mathbb R $$

# %%
varbounds = np.array([[0,10],[0,10]])
vartype = np.array([['int'],['real']])

# %% [markdown]
# * dimension=2 that is number of variables is 2 x and y
# * variable_type_mixed integer and real numbers

# %%
algorithm_param = {'max_num_iteration': 100,\
                   'population_size':100,\
                   'mutation_probability':0.1,\
                   'elit_ratio': 0.01,\
                   'crossover_probability': 0.5,\
                   'parents_portion': 0.3,\
                   'crossover_type':'uniform',\
                   'max_iteration_without_improv':None}

model = ga(function=f,dimension=2,variable_type_mixed=vartype,variable_boundaries=varbounds,algorithm_parameters=algorithm_param)

model.run()
# Out:
# ||________________________________________________ 3.0% GA is running...
# C:\Users\aduzo\Anaconda3\lib\site-packages\geneticalgorithm\geneticalgorithm.py:353: RuntimeWarning: invalid value encountered in subtract
#   normobj=maxnorm-normobj+1
#  The best solution found:
#  [5.         1.28343844]
#
#  Objective function:
#  -11.417192200415661
